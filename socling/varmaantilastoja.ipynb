# %%
# packages

import json
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
# data
df = pd.read_csv("alldata.csv", sep="\t")
df=df.drop(df.columns[0], axis=1)
df=df.drop(df.columns[0], axis=1)

# %%
df.head()
# Out:
#               speaker        date  \
# 0       Heidi Hautala  2009-02-05
# 1  Toimi Kankaanniemi  2009-02-05
# 2       Timo Heinonen  2009-02-05
# 3     Tuulikki Ukkola  2009-02-05
# 4         Juha Hakola  2009-02-05
#
#                                             sentence  session  \
# 0  Jos tämä nyt on vielä sopimatta niin siitä var...  2009-02
# 1  Tuo jo toistakymmentä vuotta Suomenkin osalta ...  2009-02
# 2  Mutta kun häiriköinti jatkuu ja on systemaatti...  2009-02
# 3  Minua ne eivät häiritse eivätkä varmaan häirit...  2009-02
# 4  Ensinnäkin se että varmaan tekin tiedätte että...  2009-02
#
#                  name gender party_y cleanbirthyear cleanbirthplace   adverb  \
# 0       Heidi Hautala      f    vihr           1955            Oulu  varmaan
# 1  Toimi Kankaanniemi      m      kd           1950          Tyrvää  varmaan
# 2       Timo Heinonen      m     kok           1975           Loppi  varmaan
# 3     Tuulikki Ukkola      f     kok           1943     Taivalkoski  varmaan
# 4         Juha Hakola      m     kok           1967            Pori  varmaan
#
#    generation
# 0       195.0
# 1       195.0
# 2       197.0
# 3       194.0
# 4       196.0
